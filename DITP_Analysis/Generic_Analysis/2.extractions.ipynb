# %% [markdown]
# # Extractions
#
# The objective of this notebook is to generate extractions from the verbatims.

# %%
import pandas as pd
import json

from tqdm import tqdm
from typing import List, Dict
from pymongo import MongoClient

import boto3

from utils.extractions_utils import generate_extractions, split_text_parts, get_extractions, add_extractions_to_splitted_analysis

# %%
STAGE = 'prod'

# %% [markdown]
# Loading all key libraries

# %%
_secrets_manager_client = boto3.client("secretsmanager", region_name="eu-west-3")

_secrets = json.loads(
    _secrets_manager_client.get_secret_value(
        SecretId=f"{STAGE.capitalize()}/alloreview"
    )["SecretString"]
)
MONGO_CONNECTION_STRING = (
    "mongodb+srv://alloreview:{}@feedbacksdev.cuwx1.mongodb.net".format(
        _secrets["mongodb"]["password"]
    )
)

OPENAI_API_KEY = _secrets["openai"]["api_key"]
LLM_API_KEY = _secrets["litellm"]["api_key"]

# %%
mongo_client = MongoClient(MONGO_CONNECTION_STRING)

collection = mongo_client['feedbacks_db']['feedbacks_Prod']

# %% [markdown]
# Define the brand and a short description of the brand.
#
# Here `columbuscafe_test` is a brand for testing purposes.

# %%
BRAND = 'columbuscafe_test'

BRAND_DESCR = '''
Feedbacks are from client of columbus cafe.
Columbus Café & Co est une chaîne française de cafés.
'''

# %%
from_mongo = pd.DataFrame(list(collection.aggregate([
    {
        '$match': {
            'brand': BRAND,
        },
    },
])))

from_mongo.shape
# Out:
# (2994, 14)

# %% [markdown]
# Displaying a random verbatim to understand the data.

# %%
row = from_mongo.sample().iloc[0]
text = row.verbatim['text']
#text = row['commentaires']
print(text)
# Out:
# Un lieu qui été bien meilleure au début... Tout nouveau tout beau ....
# Personnel toujours agréable mais ...
# Produits médiocre un café qui a la couleur du thé .
# Un latté de l'ours qui a peu de goût contrairement à celui de calais ....
# Et pour finir un restaurant qui devient vetuste et dont certaines odeurs laisse a désirer .
# En résumé dernière visite dans ce colombus.

# %% [markdown]
# First we will split our text into different parts by using punctuation.

# %%
text_parts = split_text_parts(text)

text_parts
# Out:
# [{'text': 'Un lieu qui été bien meilleure au début...'},
#  {'text': ' Tout nouveau tout beau ....\n'},
#  {'text': 'Personnel toujours agréable mais ...\n'},
#  {'text': 'Produits médiocre un café qui a la couleur du thé .\n'},
#  {'text': "Un latté de l'ours qui a peu de goût contrairement à celui de calais ....\n"},
#  {'text': 'Et pour finir un restaurant qui devient vetuste et dont certaines odeurs laisse a désirer .\n'},
#  {'text': 'En résumé dernière visite dans ce colombus.'}]

# %% [markdown]
# Then this is an example of generating extractions from the text parts.

# %%
result = get_extractions(
    text=text,
    id=row['id'],
    brand_descr=BRAND_DESCR,
    language='french',
    model='gpt-4o-mini'
)

extractions = result.get('extraction')

splitted_analysis = result.get('splitted_analysis')

# %%
extractions
# Out:
# [{'sentiment': 'NEGATIVE',
#   'extraction': "Lieu moins bon qu'au début",
#   'text': 'Un lieu qui été bien meilleure au début...'},
#  {'sentiment': 'POSITIVE',
#   'extraction': 'Personnel toujours agréable',
#   'text': 'Personnel toujours agréable mais ...\n'},
#  {'sentiment': 'NEGATIVE',
#   'extraction': 'Produits médiocres',
#   'text': 'Produits médiocre un café qui a la couleur du thé .\n'},
#  {'sentiment': 'NEGATIVE',
#   'extraction': "Latté de l'ours peu de goût",
#   'text': "Un latté de l'ours qui a peu de goût contrairement à celui de calais ....\n"},
#  {'sentiment': 'NEGATIVE',
#   'extraction': 'Restaurant vétuste avec des odeurs désagréables',
#   'text': 'Et pour finir un restaurant qui devient vetuste et dont certaines odeurs laisse a désirer .\n'},
#  {'sentiment': 'NEGATIVE',
#   'extraction': 'Dernière visite décevante',
#   'text': 'En résumé dernière visite dans ce colombus.'}]

# %% [markdown]
# In  `splitted_analysis` we reassemble the extractions with the corresponding text parts

# %%
splitted_analysis
# Out:
# [{'text': 'Un lieu qui été bien meilleure au début...',
#   'extractions': [{'sentiment': 'NEGATIVE',
#     'extraction': "Lieu moins bon qu'au début"}]},
#  {'text': ' Tout nouveau tout beau ....\n'},
#  {'text': 'Personnel toujours agréable mais ...\n',
#   'extractions': [{'sentiment': 'POSITIVE',
#     'extraction': 'Personnel toujours agréable'}]},
#  {'text': 'Produits médiocre un café qui a la couleur du thé .\n',
#   'extractions': [{'sentiment': 'NEGATIVE',
#     'extraction': 'Produits médiocres'}]},
#  {'text': "Un latté de l'ours qui a peu de goût contrairement à celui de calais ....\n",
#   'extractions': [{'sentiment': 'NEGATIVE',
#     'extraction': "Latté de l'ours peu de goût"}]},
#  {'text': 'Et pour finir un restaurant qui devient vetuste et dont certaines odeurs laisse a désirer .\n',
#   'extractions': [{'sentiment': 'NEGATIVE',
#     'extraction': 'Restaurant vétuste avec des odeurs désagréables'}]},
#  {'text': 'En résumé dernière visite dans ce colombus.',
#   'extractions': [{'sentiment': 'NEGATIVE',
#     'extraction': 'Dernière visite décevante'}]}]

# %% [markdown]
# ## Run the extraction pipeline

# %%
# this function allows to parallelize the extraction process and to save the results on the mongo database
from utils.extractions_utils import run_extractions_full_parallel

# %%
subdf = from_mongo.sample(20) # test on a subset
print('To extract:', subdf.shape[0])

subdf['text'] = subdf.verbatim.apply(lambda x: x['text'] if isinstance(x, dict) and 'text' in x else '',)
texts_with_ids = subdf[['text', '_id']].to_dict(orient='records')

# %%
extractions = run_extractions_full_parallel(
    texts_with_ids,
    BRAND,
    brand_descr=BRAND_DESCR,
    language='french',
    model="gpt-4o-mini",
    save_to_mongo=True
)
# Out:
# Processing chunks:   0%|          | 0/1 [00:00<?, ?it/s]
# [parse_extraction()] Il semble que vous n'ayez pas fourni de texte à analyser. Veuillez soumettre le texte contenant les retours des clients de Columbus Café & Co, et je pourrai alors extraire les informations pertinentes en suivant vos instructions. unexpected EOF while parsing (<string>, line 0)
#  columbuscafe_test/1fd3f4ab1be2aaacc937
# [get_extractions()] 'text'
# Processing chunks: 100%|██████████| 1/1 [00:07<00:00,  7.26s/it]

# %%
extractions
# Out:
# [{'id': 'columbuscafe_test/f6790519b4ff3fd7b410',
#   'splitted_analysis': [{'text': 'Je viens régulièrement prendre mon petit moka au colombus et c’est toujours un plaisir d’être reçu par Iris qui est souriante et serviable !',
#     'extractions': [{'sentiment': 'POSITIVE',
#       'extraction': "Satisfaction de l'accueil par Iris"}]},
#    {'text': ' De plus,'},
#    {'text': ' son moka est exceptionnel 🤩',
#     'extractions': [{'sentiment': 'POSITIVE',
#       'extraction': 'Moka exceptionnel'}]}],
#   'extraction': [{'sentiment': 'POSITIVE',
#     'extraction': "Satisfaction de l'accueil par Iris",
#     'text': 'Je viens régulièrement prendre mon petit moka au colombus et c’est toujours un plaisir d’être reçu par Iris qui est souriante et serviable !'},
#    {'sentiment': 'POSITIVE',
#     'extraction': 'Moka exceptionnel',
#     'text': ' son moka est exceptionnel 🤩'}]},
#  {'id': 'columbuscafe_test/a965ce53ffc4263dd876',
#   'splitted_analysis': [{'text': 'Très propre le personnel est très aimable je vous le conseille à 100%',
#     'extractions': [{'sentiment': 'POSITIVE',
#       'extraction': 'Établissement très propre'},
#      {'sentiment': 'POSITIVE', 'extraction': 'Personnel très aimable'},
#      {'sentiment': 'POSITIVE', 'extraction': 'Recommandation à 100%'}]}],
#   'extraction': [{'sentiment': 'POSITIVE',
#     'extraction': 'Établissement très propre',
#     'text': 'Très propre le personnel est très aimable je vous le conseille à 100%'},
#    {'sentiment': 'POSITIVE',
#     'extraction': 'Personnel très aimable',
#     'text': 'Très propre le personnel est très aimable je vous le conseille à 100%'},
#    {'sentiment': 'POSITIVE',
#     'extraction': 'Recommandation à 100%',
#     'text': 'Très propre le personnel est très aimable je vous le conseille à 100%'}]},
#  {'id': 'columbuscafe_test/91ac4fb172ed69326b8f',
#   'splitted_analysis': [{'text': 'Demandé un chocolat chaud il est tiède.',
#     'extractions': [{'sentiment': 'NEGATIVE',
#       'extraction': 'Chocolat chaud tiède'}]},
#    {'text': " De olus aucune tranquillité avec le télétravail c'est très désagréable d'entendre la conversation des uns et des autres.",
#     'extractions': [{'sentiment': 'NEGATIVE',
#       'extraction': 'Manque de tranquillité avec le télétravail'}]},
#    {'text': ' A revoir',
#     'extractions': [{'sentiment': 'SUGGESTION', 'extraction': 'À revoir'}]}],
#   'extraction': [{'sentiment': 'NEGATIVE',
#     'extraction': 'Chocolat chaud tiède',
#     'text': 'Demandé un chocolat chaud il est tiède.'},
#    {'sentiment': 'NEGATIVE',
#     'extraction': 'Manque de tranquillité avec le télétravail',
#     'text': " De olus aucune tranquillité avec le télétravail c'est très désagréable d'entendre la conversation des uns et des autres."},
#    {'sentiment': 'SUGGESTION',
#     'extraction': 'À revoir',
#     'text': ' A revoir'}]},
#  {'id': 'columbuscafe_test/5b6e404652649c8ae22e',
#   'splitted_analysis': [{'text': '2👍',
#     'extractions': [{'sentiment': 'POSITIVE',
#       'extraction': 'Appréciation générale'}]}],
#   'extraction': [{'sentiment': 'POSITIVE',
#     'extraction': 'Appréciation générale',
#     'text': '2👍'}]},
#  {'id': 'columbuscafe_test/99f4f98c955bf4295710',
#   'splitted_analysis': [{'text': "Je suis une habituée du Columbus mais c'était une première pour moi à celui de Dreux."},
#    {'text': ' La serveuse était super sympa.',
#     'extractions': [{'sentiment': 'POSITIVE',
#       'extraction': 'Serveuse sympathique'}]},
#    {'text': ' Agréable et souriante.',
#     'extractions': [{'sentiment': 'POSITIVE',
#       'extraction': 'Serveuse agréable et souriante'}]},
#    {'text': " En revanche le muffin n'était pas très bon.",
#     'extractions': [{'sentiment': 'NEGATIVE',
#       'extraction': 'Muffin pas très bon'}]},
#    {'text': ' Très sec.',
#     'extractions': [{'sentiment': 'NEGATIVE',
#       'extraction': 'Muffin très sec'}]},
#    {'text': " Il n'avait probablement pas été cuit du jour.",
#     'extractions': [{'sentiment': 'NEGATIVE',
#       'extraction': 'Muffin probablement pas cuit du jour'}]},
#    {'text': " J'étais un peu déçue",
#     'extractions': [{'sentiment': 'NEGATIVE',
#       'extraction': 'Déception concernant le muffin'}]}],
#   'extraction': [{'sentiment': 'POSITIVE',
#     'extraction': 'Serveuse sympathique',
#     'text': ' La serveuse était super sympa.'},
#    {'sentiment': 'POSITIVE',
#     'extraction': 'Serveuse agréable et souriante',
#     'text': ' Agréable et souriante.'},
#    {'sentiment': 'NEGATIVE',
#     'extraction': 'Muffin pas très bon',
#     'text': " En revanche le muffin n'était pas très bon."},
#    {'sentiment': 'NEGATIVE',
#     'extraction': 'Muffin très sec',
#     'text': ' Très sec.'},
#    {'sentiment': 'NEGATIVE',
#     'extraction': 'Muffin probablement pas cuit du jour',
#     'text': " Il n'avait probablement pas été cuit du jour."},
#    {'sentiment': 'NEGATIVE',
#     'extraction': 'Déception concernant le muffin',
#     'text': " J'étais un peu déçue"}]},
#  {'id': 'columbuscafe_test/b63067c35f9c65a8b052',
#   'splitted_analysis': [{'text': 'Vraiment un très bon accuei avec le sourire le personnel est adorable,',
#     'extractions': [{'sentiment': 'POSITIVE',
#       'extraction': 'Accueil chaleureux avec le sourire'}]},
#    {'text': ' le café est trop top,',
#     'extractions': [{'sentiment': 'POSITIVE',
#       'extraction': 'Café de qualité'}]},
#    {'text': ' les autres boissons sont super,',
#     'extractions': [{'sentiment': 'POSITIVE',
#       'extraction': 'Boissons appréciées'}]},
#    {'text': ' et les gâteaux,',
#     'extractions': [{'sentiment': 'POSITIVE',
#       'extraction': 'Gâteaux de qualité'}]},
#    {'text': ' sandwichs,',
#     'extractions': [{'sentiment': 'POSITIVE',
#       'extraction': 'Sandwichs de qualité'}]},
#    {'text': ' salades sont tout simplement sublimes,',
#     'extractions': [{'sentiment': 'POSITIVE',
#       'extraction': 'Salades de qualité'}]},
#    {'text': ' je recommande vivement.',
#     'extractions': [{'sentiment': 'POSITIVE',
#       'extraction': 'Recommandation du café'}]}],
#   'extraction': [{'sentiment': 'POSITIVE',
#     'extraction': 'Accueil chaleureux avec le sourire',
#     'text': 'Vraiment un très bon accuei avec le sourire le personnel est adorable,'},
#    {'sentiment': 'POSITIVE',
#     'extraction': 'Café de qualité',
#     'text': ' le café est trop top,'},
#    {'sentiment': 'POSITIVE',
#     'extraction': 'Boissons appréciées',
#     'text': ' les autres boissons sont super,'},
#    {'sentiment': 'POSITIVE',
#     'extraction': 'Gâteaux de qualité',
#     'text': ' et les gâteaux,'},
#    {'sentiment': 'POSITIVE',
#     'extraction': 'Sandwichs de qualité',
#     'text': ' sandwichs,'},
#    {'sentiment': 'POSITIVE',
#     'extraction': 'Salades de qualité',
#     'text': ' salades sont tout simplement sublimes,'},
#    {'sentiment': 'POSITIVE',
#     'extraction': 'Recommandation du café',
#     'text': ' je recommande vivement.'}]},
#  {'id': 'columbuscafe_test/5134f5a2d1a4b013659f',
#   'splitted_analysis': [{'text': 'Nourriture bonne et la personne au caisse très souriante',
#     'extractions': [{'sentiment': 'POSITIVE',
#       'extraction': 'Nourriture bonne'},
#      {'sentiment': 'POSITIVE',
#       'extraction': 'Personne à la caisse très souriante'}]}],
#   'extraction': [{'sentiment': 'POSITIVE',
#     'extraction': 'Nourriture bonne',
#     'text': 'Nourriture bonne et la personne au caisse très souriante'},
#    {'sentiment': 'POSITIVE',
#     'extraction': 'Personne à la caisse très souriante',
#     'text': 'Nourriture bonne et la personne au caisse très souriante'}]},
#  {'id': 'columbuscafe_test/f75b1294c3b09d36be07',
#   'splitted_analysis': [{'text': 'Personnelles toujours sympathique bon produit\n\n',
#     'extractions': [{'sentiment': 'POSITIVE',
#       'extraction': 'Personnel sympathique'},
#      {'sentiment': 'POSITIVE', 'extraction': 'Produits de qualité'}]},
#    {'text': 'Kid-friendliness: Il y a de tout même pour les enfants\n\n',
#     'extractions': [{'sentiment': 'POSITIVE',
#       'extraction': 'Options adaptées aux enfants'}]},
#    {'text': 'Parking: Grand parking',
#     'extractions': [{'sentiment': 'POSITIVE',
#       'extraction': 'Grand parking disponible'}]}],
#   'extraction': [{'sentiment': 'POSITIVE',
#     'extraction': 'Personnel sympathique',
#     'text': 'Personnelles toujours sympathique bon produit\n\n'},
#    {'sentiment': 'POSITIVE',
#     'extraction': 'Produits de qualité',
#     'text': 'Personnelles toujours sympathique bon produit\n\n'},
#    {'sentiment': 'POSITIVE',
#     'extraction': 'Options adaptées aux enfants',
#     'text': 'Kid-friendliness: Il y a de tout même pour les enfants\n\n'},
#    {'sentiment': 'POSITIVE',
#     'extraction': 'Grand parking disponible',
#     'text': 'Parking: Grand parking'}]},
#  {'id': 'columbuscafe_test/09849c25a5224e258d60',
#   'splitted_analysis': [{'text': 'Très bon accueil,',
#     'extractions': [{'sentiment': 'POSITIVE',
#       'extraction': 'Très bon accueil'}]},
#    {'text': ' très bon service.',
#     'extractions': [{'sentiment': 'POSITIVE',
#       'extraction': 'Très bon service'}]},
#    {'text': ' Personnel très agréable,',
#     'extractions': [{'sentiment': 'POSITIVE',
#       'extraction': 'Personnel très agréable'}]},
#    {'text': ' surtout le grand blond très sympathique.',
#     'extractions': [{'sentiment': 'POSITIVE',
#       'extraction': 'Grand blond très sympathique'}]},
#    {'text': ' À recommander !',
#     'extractions': [{'sentiment': 'POSITIVE',
#       'extraction': 'À recommander'}]}],
#   'extraction': [{'sentiment': 'POSITIVE',
#     'extraction': 'Très bon accueil',
#     'text': 'Très bon accueil,'},
#    {'sentiment': 'POSITIVE',
#     'extraction': 'Très bon service',
#     'text': ' très bon service.'},
#    {'sentiment': 'POSITIVE',
#     'extraction': 'Personnel très agréable',
#     'text': ' Personnel très agréable,'},
#    {'sentiment': 'POSITIVE',
#     'extraction': 'Grand blond très sympathique',
#     'text': ' surtout le grand blond très sympathique.'},
#    {'sentiment': 'POSITIVE',
#     'extraction': 'À recommander',
#     'text': ' À recommander !'}]},
#  {'id': 'columbuscafe_test/b037567cc8a63491a436',
#   'splitted_analysis': [{'text': 'Sympa beau décor bel accueil',
#     'extractions': [{'sentiment': 'POSITIVE', 'extraction': 'Décor agréable'},
#      {'sentiment': 'POSITIVE', 'extraction': 'Accueil chaleureux'}]}],
#   'extraction': [{'sentiment': 'POSITIVE',
#     'extraction': 'Décor agréable',
#     'text': 'Sympa beau décor bel accueil'},
#    {'sentiment': 'POSITIVE',
#     'extraction': 'Accueil chaleureux',
#     'text': 'Sympa beau décor bel accueil'}]},
#  {'id': 'columbuscafe_test/6e5641974a4d3ce0e1dc',
#   'splitted_analysis': [{'text': "Les produits sont excellents et l'accueil est un vrai bonheur également !",
#     'extractions': [{'sentiment': 'POSITIVE',
#       'extraction': 'Produits excellents'},
#      {'sentiment': 'POSITIVE', 'extraction': 'Accueil agréable'}]}],
#   'extraction': [{'sentiment': 'POSITIVE',
#     'extraction': 'Produits excellents',
#     'text': "Les produits sont excellents et l'accueil est un vrai bonheur également !"},
#    {'sentiment': 'POSITIVE',
#     'extraction': 'Accueil agréable',
#     'text': "Les produits sont excellents et l'accueil est un vrai bonheur également !"}]},
#  {'id': 'columbuscafe_test/722ce06532cc08480852',
#   'splitted_analysis': [{'text': 'La serveuse est souriante et rapide.\n',
#     'extractions': [{'sentiment': 'POSITIVE',
#       'extraction': 'Serveuse souriante'},
#      {'sentiment': 'POSITIVE', 'extraction': 'Serveuse rapide'}]},
#    {'text': 'Elle n’hésite pas à arranger le client.\n',
#     'extractions': [{'sentiment': 'POSITIVE',
#       'extraction': 'Serveuse arrange le client'}]},
#    {'text': 'Les boissons latte et cookies sont très gourmand.',
#     'extractions': [{'sentiment': 'POSITIVE',
#       'extraction': 'Boissons latte et cookies très gourmandes'}]},
#    {'text': ' (Personnellement jadoooooore le matcha coco glacé ❤️)\n',
#     'extractions': [{'sentiment': 'POSITIVE',
#       'extraction': 'Aime le matcha coco glacé'}]},
#    {'text': 'Concernant le lieu,'},
#    {'text': ' il y a quelques travaux a prévoir (peinture,',
#     'extractions': [{'sentiment': 'SUGGESTION',
#       'extraction': 'Travaux à prévoir dans le lieu'}]},
#    {'text': ' lumière défaillante).',
#     'extractions': [{'sentiment': 'SUGGESTION',
#       'extraction': 'Travaux à prévoir dans le lieu'}]},
#    {'text': ' Quand nous sommes venu,'},
#    {'text': ' il y avait des ruptures,',
#     'extractions': [{'sentiment': 'NEGATIVE',
#       'extraction': 'Ruptures de stock'}]},
#    {'text': ' attention aux stocks.\n',
#     'extractions': [{'sentiment': 'SUGGESTION',
#       'extraction': 'Attention aux stocks'}]},
#    {'text': 'Je recommande !',
#     'extractions': [{'sentiment': 'POSITIVE',
#       'extraction': 'Recommandation du café'}]}],
#   'extraction': [{'sentiment': 'POSITIVE',
#     'extraction': 'Serveuse souriante',
#     'text': 'La serveuse est souriante et rapide.\n'},
#    {'sentiment': 'POSITIVE',
#     'extraction': 'Serveuse rapide',
#     'text': 'La serveuse est souriante et rapide.\n'},
#    {'sentiment': 'POSITIVE',
#     'extraction': 'Serveuse arrange le client',
#     'text': 'Elle n’hésite pas à arranger le client.\n'},
#    {'sentiment': 'POSITIVE',
#     'extraction': 'Boissons latte et cookies très gourmandes',
#     'text': 'Les boissons latte et cookies sont très gourmand.'},
#    {'sentiment': 'POSITIVE',
#     'extraction': 'Aime le matcha coco glacé',
#     'text': ' (Personnellement jadoooooore le matcha coco glacé ❤️)\n'},
#    {'sentiment': 'SUGGESTION',
#     'extraction': 'Travaux à prévoir dans le lieu',
#     'text': ' il y a quelques travaux a prévoir (peinture,'},
#    {'sentiment': 'SUGGESTION',
#     'extraction': 'Travaux à prévoir dans le lieu',
#     'text': ' lumière défaillante).'},
#    {'sentiment': 'NEGATIVE',
#     'extraction': 'Ruptures de stock',
#     'text': ' il y avait des ruptures,'},
#    {'sentiment': 'SUGGESTION',
#     'extraction': 'Attention aux stocks',
#     'text': ' attention aux stocks.\n'},
#    {'sentiment': 'POSITIVE',
#     'extraction': 'Recommandation du café',
#     'text': 'Je recommande !'}]},
#  {'id': 'columbuscafe_test/13892e2103825cf06d02',
#   'splitted_analysis': [{'text': '1👍',
#     'extractions': [{'sentiment': 'POSITIVE',
#       'extraction': 'Appréciation générale'}]}],
#   'extraction': [{'sentiment': 'POSITIVE',
#     'extraction': 'Appréciation générale',
#     'text': '1👍'}]},
#  {'id': 'columbuscafe_test/a83b46e06e9602fdf225',
#   'splitted_analysis': [{'text': 'Très bonne expérience,',
#     'extractions': [{'sentiment': 'POSITIVE',
#       'extraction': 'Très bonne expérience'}]},
#    {'text': ' serveur agréable et à l’écoute de ses clients.',
#     'extractions': [{'sentiment': 'POSITIVE',
#       'extraction': 'Serveur agréable et à l’écoute'}]},
#    {'text': ' (Boisson élixir délicieuse citron menthe framboise  !',
#     'extractions': [{'sentiment': 'POSITIVE',
#       'extraction': 'Boisson élixir délicieuse (citron menthe framboise)'}]},
#    {'text': ') Je recommande !',
#     'extractions': [{'sentiment': 'POSITIVE',
#       'extraction': 'Recommandation du café'}]}],
#   'extraction': [{'sentiment': 'POSITIVE',
#     'extraction': 'Très bonne expérience',
#     'text': 'Très bonne expérience,'},
#    {'sentiment': 'POSITIVE',
#     'extraction': 'Serveur agréable et à l’écoute',
#     'text': ' serveur agréable et à l’écoute de ses clients.'},
#    {'sentiment': 'POSITIVE',
#     'extraction': 'Boisson élixir délicieuse (citron menthe framboise)',
#     'text': ' (Boisson élixir délicieuse citron menthe framboise  !'},
#    {'sentiment': 'POSITIVE',
#     'extraction': 'Recommandation du café',
#     'text': ') Je recommande !'}]},
#  {'id': 'columbuscafe_test/ef22c67112fc66d6aa96',
#   'splitted_analysis': [{'text': "Un peu cher pour des produits qu'ils ne font pas eux même",
#     'extractions': [{'sentiment': 'NEGATIVE',
#       'extraction': 'Produits trop chers'},
#      {'sentiment': 'NEGATIVE',
#       'extraction': 'Produits non fabriqués par Columbus Café'}]}],
#   'extraction': [{'sentiment': 'NEGATIVE',
#     'extraction': 'Produits trop chers',
#     'text': "Un peu cher pour des produits qu'ils ne font pas eux même"},
#    {'sentiment': 'NEGATIVE',
#     'extraction': 'Produits non fabriqués par Columbus Café',
#     'text': "Un peu cher pour des produits qu'ils ne font pas eux même"}]},
#  {'id': 'columbuscafe_test/6d79829dfc75c2e4ed36',
#   'splitted_analysis': [{'text': 'Toujours très bien accueillis,',
#     'extractions': [{'sentiment': 'POSITIVE',
#       'extraction': 'Accueil très bien'}]},
#    {'text': ' Une équipe super agréable,',
#     'extractions': [{'sentiment': 'POSITIVE',
#       'extraction': 'Équipe super agréable'}]},
#    {'text': ' souriante et très professionnelle.',
#     'extractions': [{'sentiment': 'POSITIVE',
#       'extraction': 'Équipe souriante et professionnelle'}]}],
#   'extraction': [{'sentiment': 'POSITIVE',
#     'extraction': 'Accueil très bien',
#     'text': 'Toujours très bien accueillis,'},
#    {'sentiment': 'POSITIVE',
#     'extraction': 'Équipe super agréable',
#     'text': ' Une équipe super agréable,'},
#    {'sentiment': 'POSITIVE',
#     'extraction': 'Équipe souriante et professionnelle',
#     'text': ' souriante et très professionnelle.'}]},
#  {'id': 'columbuscafe_test/1fd3f4ab1be2aaacc937',
#   'splitted_analysis': [],
#   'extraction': []},
#  {'id': 'columbuscafe_test/43f07543c941a5d88922',
#   'splitted_analysis': [{'text': 'Service courtois.',
#     'extractions': [{'sentiment': 'POSITIVE',
#       'extraction': 'Service courtois'}]},
#    {'text': ' Préparation des beignets par un employé exposé comme un poisson dans un aquarium.',
#     'extractions': [{'sentiment': 'NEGATIVE',
#       'extraction': 'Préparation des beignets exposée de manière peu agréable'}]},
#    {'text': ' Perso,'},
#    {'text': " je n'aimerais pas trop travaillé exposé comme ça.",
#     'extractions': [{'sentiment': 'NEGATIVE',
#       'extraction': 'Préparation des beignets exposée de manière peu agréable'}]},
#    {'text': ' Enfin.'},
#    {'text': ' Bref.'},
#    {'text': ' Petit espace sympa pour manger sur place,',
#     'extractions': [{'sentiment': 'POSITIVE',
#       'extraction': 'Petit espace sympa pour manger sur place'}]},
#    {'text': ' bien situé,',
#     'extractions': [{'sentiment': 'POSITIVE', 'extraction': 'Bien situé'}]},
#    {'text': ' sous un puit de lumière.',
#     'extractions': [{'sentiment': 'POSITIVE',
#       'extraction': 'Espace sous un puits de lumière'}]},
#    {'text': " 😎 Produits  d'excellente qualité.",
#     'extractions': [{'sentiment': 'POSITIVE',
#       'extraction': "Produits d'excellente qualité"}]},
#    {'text': ' 👍 En rapport avec 💵 dépensé.',
#     'extractions': [{'sentiment': 'POSITIVE',
#       'extraction': 'Bon rapport qualité-prix'}]},
#    {'text': ' Ça fait une bonne pause goûter au cours des courses.',
#     'extractions': [{'sentiment': 'POSITIVE',
#       'extraction': 'Bonne pause goûter pendant les courses'}]}],
#   'extraction': [{'sentiment': 'POSITIVE',
#     'extraction': 'Service courtois',
#     'text': 'Service courtois.'},
#    {'sentiment': 'NEGATIVE',
#     'extraction': 'Préparation des beignets exposée de manière peu agréable',
#     'text': ' Préparation des beignets par un employé exposé comme un poisson dans un aquarium.'},
#    {'sentiment': 'NEGATIVE',
#     'extraction': 'Préparation des beignets exposée de manière peu agréable',
#     'text': " je n'aimerais pas trop travaillé exposé comme ça."},
#    {'sentiment': 'POSITIVE',
#     'extraction': 'Petit espace sympa pour manger sur place',
#     'text': ' Petit espace sympa pour manger sur place,'},
#    {'sentiment': 'POSITIVE',
#     'extraction': 'Bien situé',
#     'text': ' bien situé,'},
#    {'sentiment': 'POSITIVE',
#     'extraction': 'Espace sous un puits de lumière',
#     'text': ' sous un puit de lumière.'},
#    {'sentiment': 'POSITIVE',
#     'extraction': "Produits d'excellente qualité",
#     'text': " 😎 Produits  d'excellente qualité."},
#    {'sentiment': 'POSITIVE',
#     'extraction': 'Bon rapport qualité-prix',
#     'text': ' 👍 En rapport avec 💵 dépensé.'},
#    {'sentiment': 'POSITIVE',
#     'extraction': 'Bonne pause goûter pendant les courses',
#     'text': ' Ça fait une bonne pause goûter au cours des courses.'}]},
#  {'id': 'columbuscafe_test/699a0ea75c0b3e677a19',
#   'splitted_analysis': [{'text': 'Super lieux je recommande',
#     'extractions': [{'sentiment': 'POSITIVE',
#       'extraction': 'Recommandation du lieu'}]}],
#   'extraction': [{'sentiment': 'POSITIVE',
#     'extraction': 'Recommandation du lieu',
#     'text': 'Super lieux je recommande'}]},
#  {'id': 'columbuscafe_test/1de034c59bebb207d616',
#   'splitted_analysis': [{'text': 'Personnel toujours agréable.\n',
#     'extractions': [{'sentiment': 'POSITIVE',
#       'extraction': 'Personnel agréable'}]},
#    {'text': 'Service impeccable.',
#     'extractions': [{'sentiment': 'POSITIVE',
#       'extraction': 'Service impeccable'}]},
#    {'text': ' J’y reviens sans hésiter.',
#     'extractions': [{'sentiment': 'POSITIVE',
#       'extraction': 'Volonté de revenir'}]},
#    {'text': ' …'}],
#   'extraction': [{'sentiment': 'POSITIVE',
#     'extraction': 'Personnel agréable',
#     'text': 'Personnel toujours agréable.\n'},
#    {'sentiment': 'POSITIVE',
#     'extraction': 'Service impeccable',
#     'text': 'Service impeccable.'},
#    {'sentiment': 'POSITIVE',
#     'extraction': 'Volonté de revenir',
#     'text': ' J’y reviens sans hésiter.'}]}]

# %% [markdown]
# ## Checking result in MongoDB

# %%
result
# Out:
# {'id': '1c59e5e7bcf3acca00b9',
#  'splitted_analysis': [{'text': 'Expérience too good to go plus que positive.',
#    'extractions': [{'sentiment': 'POSITIVE',
#      'extraction': 'Expérience positive avec too good to go'}]},
#   {'text': ' Personnel agréable et serviable.',
#    'extractions': [{'sentiment': 'POSITIVE',
#      'extraction': 'Personnel agréable et serviable'}]},
#   {'text': " J'ai eut de bons conseils pour la conservation des muffins.\n",
#    'extractions': [{'sentiment': 'POSITIVE',
#      'extraction': 'Bons conseils pour la conservation des muffins'}]},
#   {'text': 'Merci.'}],
#  'extraction': [{'sentiment': 'POSITIVE',
#    'extraction': 'Expérience positive avec too good to go',
#    'text': 'Expérience too good to go plus que positive.'},
#   {'sentiment': 'POSITIVE',
#    'extraction': 'Personnel agréable et serviable',
#    'text': ' Personnel agréable et serviable.'},
#   {'sentiment': 'POSITIVE',
#    'extraction': 'Bons conseils pour la conservation des muffins',
#    'text': " J'ai eut de bons conseils pour la conservation des muffins.\n"}]}

# %%
# getting the document from the database to check if the extractions are saved
# matching the brand and the id in res

documents = collection.find({
    'brand': BRAND,
    '_id': {'$in': [r['id'] for r in extractions]}
})

documents = pd.DataFrame(documents)

# %%
documents
# Out:
#                                        _id                    id  \
# 0   columbuscafe_test/09849c25a5224e258d60  09849c25a5224e258d60
# 1   columbuscafe_test/13892e2103825cf06d02  13892e2103825cf06d02
# 2   columbuscafe_test/1de034c59bebb207d616  1de034c59bebb207d616
# 3   columbuscafe_test/1fd3f4ab1be2aaacc937  1fd3f4ab1be2aaacc937
# 4   columbuscafe_test/43f07543c941a5d88922  43f07543c941a5d88922
# 5   columbuscafe_test/5134f5a2d1a4b013659f  5134f5a2d1a4b013659f
# 6   columbuscafe_test/5b6e404652649c8ae22e  5b6e404652649c8ae22e
# 7   columbuscafe_test/699a0ea75c0b3e677a19  699a0ea75c0b3e677a19
# 8   columbuscafe_test/6d79829dfc75c2e4ed36  6d79829dfc75c2e4ed36
# 9   columbuscafe_test/6e5641974a4d3ce0e1dc  6e5641974a4d3ce0e1dc
# 10  columbuscafe_test/722ce06532cc08480852  722ce06532cc08480852
# 11  columbuscafe_test/91ac4fb172ed69326b8f  91ac4fb172ed69326b8f
# 12  columbuscafe_test/99f4f98c955bf4295710  99f4f98c955bf4295710
# 13  columbuscafe_test/a83b46e06e9602fdf225  a83b46e06e9602fdf225
# 14  columbuscafe_test/a965ce53ffc4263dd876  a965ce53ffc4263dd876
# 15  columbuscafe_test/b037567cc8a63491a436  b037567cc8a63491a436
# 16  columbuscafe_test/b63067c35f9c65a8b052  b63067c35f9c65a8b052
# 17  columbuscafe_test/ef22c67112fc66d6aa96  ef22c67112fc66d6aa96
# 18  columbuscafe_test/f6790519b4ff3fd7b410  f6790519b4ff3fd7b410
# 19  columbuscafe_test/f75b1294c3b09d36be07  f75b1294c3b09d36be07
#
#                 brand     timestamp  \
# 0   columbuscafe_test  1.682640e+12
# 1   columbuscafe_test  1.690416e+12
# 2   columbuscafe_test  1.691885e+12
# 3   columbuscafe_test  1.683850e+12
# 4   columbuscafe_test  1.681344e+12
# 5   columbuscafe_test  1.689293e+12
# 6   columbuscafe_test  1.696810e+12
# 7   columbuscafe_test  1.690502e+12
# 8   columbuscafe_test  1.689120e+12
# 9   columbuscafe_test  1.685232e+12
# 10  columbuscafe_test  1.690675e+12
# 11  columbuscafe_test  1.689034e+12
# 12  columbuscafe_test  1.694390e+12
# 13  columbuscafe_test  1.696637e+12
# 14  columbuscafe_test  1.692403e+12
# 15  columbuscafe_test  1.682986e+12
# 16  columbuscafe_test  1.697242e+12
# 17  columbuscafe_test  1.681171e+12
# 18  columbuscafe_test  1.691021e+12
# 19  columbuscafe_test  1.683331e+12
#
#                                              verbatim  \
# 0   {'text': 'Très bon accueil, très bon service. ...
# 1                                      {'text': '1👍'}
# 2   {'text': 'Personnel toujours agréable.
# Service...
# 3                                                  {}
# 4   {'text': 'Service courtois. Préparation des be...
# 5   {'text': 'Nourriture bonne et la personne au c...
# 6                                      {'text': '2👍'}
# 7               {'text': 'Super lieux je recommande'}
# 8   {'text': 'Toujours très bien accueillis, Une é...
# 9   {'text': 'Les produits sont excellents et l'ac...
# 10  {'text': 'La serveuse est souriante et rapide....
# 11  {'text': 'Demandé un chocolat chaud il est tiè...
# 12  {'text': 'Je suis une habituée du Columbus mai...
# 13  {'text': 'Très bonne expérience, serveur agréa...
# 14  {'text': 'Très propre le personnel est très ai...
# 15           {'text': 'Sympa beau décor bel accueil'}
# 16  {'text': 'Vraiment un très bon accuei avec le ...
# 17  {'text': 'Un peu cher pour des produits qu'ils...
# 18  {'text': 'Je viens régulièrement prendre mon p...
# 19  {'text': 'Personnelles toujours sympathique bo...
#
#                      establishment review_site               author  \
# 0           Carcassonne Pont Rouge      Google    Sophie Chioccioli
# 1            Aix-en-Provence Masse   Uber Eats              Ambre G
# 2                 Toulouse Compans      Google       Justine Pécheu
# 3                  Collégien Bay 2      Google           nabia klai
# 4                        Vitrimont      Google       Steve Boudrias
# 5                  Gemo Mondeville      Google        aicha elackal
# 6              Lyon Frères Lumière   Uber Eats             Thomas B
# 7       Valenciennes Place d'Armes      Google     francois drapier
# 8           Carcassonne Pont Rouge      Google                  K B
# 9                           Colmar      Google         Muriel FLUCK
# 10                Rouen Champmesle      Google        Amélie MENANT
# 11                       Levallois      Google     Liliane Piednoir
# 12                           Dreux      Google      Laurie Chichery
# 13            Grenoble Grand'Place      Google              RUBIS O
# 14                          Olivet      Google        {leïla gacha}
# 15                         Ajaccio      Google      Patrick LUCIANI
# 16          Carcassonne Pont Rouge      Google        Georges Bolan
# 17                      Vénissieux      Google  Sandrine Bichwiller
# 18  Centre commercial Carré Sénart      Google      Franck Belgrand
# 19      Noisy-Le-Grand Les Arcades      Google        Natacha Yzeux
#
#     rating_out_of_5 language  \
# 0               5.0       fr
# 1               5.0       fr
# 2               5.0       fr
# 3               3.0       fr
# 4               4.0       fr
# 5               5.0       fr
# 6               5.0       fr
# 7               5.0       fr
# 8               5.0       fr
# 9               5.0       fr
# 10              5.0       fr
# 11              1.0       fr
# 12              3.0       fr
# 13              5.0       fr
# 14              5.0       fr
# 15              4.0       fr
# 16              5.0       fr
# 17              2.0       fr
# 18              5.0       fr
# 19              5.0       fr
#
#                                           extractions  \
# 0   [{'sentiment': 'POSITIVE', 'extraction': 'Très...
# 1   [{'sentiment': 'POSITIVE', 'extraction': 'Appr...
# 2   [{'sentiment': 'POSITIVE', 'extraction': 'Pers...
# 3                                                  []
# 4   [{'sentiment': 'POSITIVE', 'extraction': 'Serv...
# 5   [{'sentiment': 'POSITIVE', 'extraction': 'Nour...
# 6   [{'sentiment': 'POSITIVE', 'extraction': 'Appr...
# 7   [{'sentiment': 'POSITIVE', 'extraction': 'Reco...
# 8   [{'sentiment': 'POSITIVE', 'extraction': 'Accu...
# 9   [{'sentiment': 'POSITIVE', 'extraction': 'Prod...
# 10  [{'sentiment': 'POSITIVE', 'extraction': 'Serv...
# 11  [{'sentiment': 'NEGATIVE', 'extraction': 'Choc...
# 12  [{'sentiment': 'POSITIVE', 'extraction': 'Serv...
# 13  [{'sentiment': 'POSITIVE', 'extraction': 'Très...
# 14  [{'sentiment': 'POSITIVE', 'extraction': 'Étab...
# 15  [{'sentiment': 'POSITIVE', 'extraction': 'Déco...
# 16  [{'sentiment': 'POSITIVE', 'extraction': 'Accu...
# 17  [{'sentiment': 'NEGATIVE', 'extraction': 'Prod...
# 18  [{'sentiment': 'POSITIVE', 'extraction': 'Sati...
# 19  [{'sentiment': 'POSITIVE', 'extraction': 'Pers...
#
#                                  splitted_analysis_v2          review_title  \
# 0   [{'text': 'Très bon accueil,', 'extractions': ...                   NaN
# 1   [{'text': '1👍', 'extractions': [{'sentiment': ...  27-07-2023 - 14.8EUR
# 2   [{'text': 'Personnel toujours agréable.
# ', 'ex...                   NaN
# 3                                                  []                   NaN
# 4   [{'text': 'Service courtois.', 'extractions': ...                   NaN
# 5   [{'text': 'Nourriture bonne et la personne au ...                   NaN
# 6   [{'text': '2👍', 'extractions': [{'sentiment': ...  08-10-2023 - 15.7EUR
# 7   [{'text': 'Super lieux je recommande', 'extrac...                   NaN
# 8   [{'text': 'Toujours très bien accueillis,', 'e...                   NaN
# 9   [{'text': 'Les produits sont excellents et l'a...                   NaN
# 10  [{'text': 'La serveuse est souriante et rapide...                   NaN
# 11  [{'text': 'Demandé un chocolat chaud il est ti...                   NaN
# 12  [{'text': 'Je suis une habituée du Columbus ma...                   NaN
# 13  [{'text': 'Très bonne expérience,', 'extractio...                   NaN
# 14  [{'text': 'Très propre le personnel est très a...                   NaN
# 15  [{'text': 'Sympa beau décor bel accueil', 'ext...                   NaN
# 16  [{'text': 'Vraiment un très bon accuei avec le...                   NaN
# 17  [{'text': 'Un peu cher pour des produits qu'il...                   NaN
# 18  [{'text': 'Je viens régulièrement prendre mon ...                   NaN
# 19  [{'text': 'Personnelles toujours sympathique b...                   NaN
#
#                                     splitted_analysis  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5   [{'text': 'Nourriture bonne et la personne au ...
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
#
#                                                topics
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5   [{'topic': {'1': 'Personnel', '2': 'Aimabilité...
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN

# %%
documents.sample().iloc[0].extractions
# Out:
# [{'sentiment': 'POSITIVE',
#   'extraction': 'Serveuse souriante',
#   'text': 'La serveuse est souriante et rapide.\n'},
#  {'sentiment': 'POSITIVE',
#   'extraction': 'Serveuse rapide',
#   'text': 'La serveuse est souriante et rapide.\n'},
#  {'sentiment': 'POSITIVE',
#   'extraction': 'Serveuse arrange le client',
#   'text': 'Elle n’hésite pas à arranger le client.\n'},
#  {'sentiment': 'POSITIVE',
#   'extraction': 'Boissons latte et cookies très gourmandes',
#   'text': 'Les boissons latte et cookies sont très gourmand.'},
#  {'sentiment': 'POSITIVE',
#   'extraction': 'Aime le matcha coco glacé',
#   'text': ' (Personnellement jadoooooore le matcha coco glacé ❤️)\n'},
#  {'sentiment': 'SUGGESTION',
#   'extraction': 'Travaux à prévoir dans le lieu',
#   'text': ' il y a quelques travaux a prévoir (peinture,'},
#  {'sentiment': 'SUGGESTION',
#   'extraction': 'Travaux à prévoir dans le lieu',
#   'text': ' lumière défaillante).'},
#  {'sentiment': 'NEGATIVE',
#   'extraction': 'Ruptures de stock',
#   'text': ' il y avait des ruptures,'},
#  {'sentiment': 'SUGGESTION',
#   'extraction': 'Attention aux stocks',
#   'text': ' attention aux stocks.\n'},
#  {'sentiment': 'POSITIVE',
#   'extraction': 'Recommandation du café',
#   'text': 'Je recommande !'}]

# %%
documents.sample().iloc[0].splitted_analysis_v2
# Out:
# [{'text': "Un peu cher pour des produits qu'ils ne font pas eux même",
#   'extractions': [{'sentiment': 'NEGATIVE',
#     'extraction': 'Produits trop chers'},
#    {'sentiment': 'NEGATIVE',
#     'extraction': 'Produits non fabriqués par Columbus Café'}]}]
